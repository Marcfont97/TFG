# %% [markdown]
# ## TRATAMIENTO DATASET

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import cv2
import os
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14,9]

import collections
from PIL import Image

from fastai import *
from fastai.callbacks import *
from fastai.vision import *
from fastai.metrics import error_rate


import fastai
fastai.__version__
# Out:
# '1.0.54'

# %%
path = Path("IMÁGENES FILTRADAS/")

# %%
path.ls()
# Out:
# [PosixPath('IMÁGENES FILTRADAS/BURKITT_32.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_6.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_20.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_16.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_21.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_10.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_110.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_48.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_85.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_73.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_7.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_138.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_44.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_147.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_62.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_10.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_135.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_6.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_23.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_107.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_31.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_51.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_3.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_18.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_56.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_85.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_96.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_122.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_108.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_19.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_123.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_24.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_31.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_40.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_10.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_79.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_125.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_124.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_31.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_2.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_42.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_155.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_114.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_59.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_5.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_119.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_69.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_11.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_28.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_186.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_33.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_17.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_43.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_5.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_92.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_5.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_14.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_139.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_118.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_15.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_30.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_128.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_177.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_131.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_53.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_68.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_41.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_35.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_36.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_15.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_109.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_9.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_106.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_3.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_134.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_113.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_16.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_83.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_7.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_130.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_41.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_45.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_159.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_41.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_52.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_39.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_18.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_72.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_50.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_88.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_132.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_167.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_162.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_143.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_50.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_26.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_24.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_3.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_58.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_37.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_4.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_142.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_117.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_40.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_12.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_78.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_138.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_97.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_151.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_29.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_77.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_105.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_11.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_101.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_45.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_47.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_46.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_103.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_93.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_153.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_59.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_58.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_11.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_61.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_121.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_146.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_33.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_44.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_104.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_94.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_156.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_2.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_9.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_97.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_47.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_176.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_106.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_94.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_163.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_52.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_17.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_5.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_187.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_26.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_64.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_13.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_131.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_43.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_118.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_30.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_51.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_38.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_110.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_54.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_128.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_108.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_51.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_30.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_6.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_86.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_141.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_120.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_52.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_166.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_145.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_1.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_47.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_49.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_139.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_7.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_96.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_149.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_172.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_50.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_20.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_25.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_137.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_93.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_71.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_155.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_66.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_20.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_39.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_87.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_8.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_12.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_1.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_70.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_36.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_58.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_154.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_15.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_104.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_34.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_46.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_121.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_148.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_185.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_148.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_13.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_98.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_33.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_127.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_134.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_23.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_180.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_112.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_28.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_8.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_19.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_79.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_26.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_157.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_2.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_45.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_24.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_22.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_37.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_82.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_37.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_54.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_53.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_178.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_127.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_27.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_182.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_2.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_135.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_55.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_12.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_91.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_37.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_71.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_19.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_80.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_164.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_1.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_36.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_175.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_1.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_67.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_100.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_4.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_37.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_117.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_25.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_53.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_35.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_55.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_4.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_25.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_67.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_57.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_63.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_188.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_22.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_15.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_189.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_36.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_49.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_23.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_42.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_19.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_95.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_129.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_184.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_179.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_8.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_72.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_133.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_12.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_100.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_126.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_39.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_45.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_18.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_76.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_32.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_142.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_89.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_42.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_98.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_38.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_88.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_69.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_158.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_57.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_26.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_49.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_17.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_136.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_78.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_13.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_57.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_27.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_154.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_70.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_28.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_132.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_146.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_18.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_89.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_42.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_14.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_36.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_22.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_6.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_81.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_75.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_123.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_174.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_40.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_34.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_46.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_76.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_153.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_14.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_49.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_65.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_26.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_32.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_113.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_183.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_39.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_171.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_44.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_50.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_34.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_115.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_20.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_55.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_105.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_75.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_39.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_130.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_84.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_158.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_27.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_19.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_10.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_1.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_63.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_74.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_35.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_18.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_151.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_80.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_161.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_48.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_13.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_91.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_115.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_17.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_9.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_17.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_21.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_30.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_32.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_47.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_45.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_156.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_43.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_33.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_126.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_46.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_83.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_92.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_9.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_87.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_24.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_144.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_29.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/models'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_31.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_30.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_48.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_95.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_44.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_55.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_66.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_31.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_60.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_34.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_114.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_42.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_4.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_74.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_14.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_90.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_3.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_59.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_20.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_165.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_173.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_40.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_7.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_38.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_56.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_21.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_6.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_28.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_24.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_159.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_41.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_140.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_77.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_25.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_56.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_157.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_107.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_11.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_11.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_27.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_53.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_40.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_43.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_22.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_2.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_169.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_99.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_47.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_56.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_124.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_102.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_152.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_52.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_125.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_10.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_5.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_4.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_9.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_51.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_34.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_13.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_84.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_25.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_16.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_101.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_103.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_136.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_29.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_86.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_43.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_99.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_32.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_81.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_27.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_109.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_102.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_38.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_48.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_170.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_8.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_46.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_16.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_141.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_116.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_14.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_160.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_54.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_111.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_48.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_21.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_116.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_57.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_7.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_3.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_38.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_23.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_62.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_61.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_12.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_147.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_65.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_16.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_28.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_33.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_82.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_60.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_120.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_22.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_181.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_145.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_64.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_137.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_73.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_122.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_35.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_44.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_133.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_149.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_68.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_119.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_8.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LCM_54.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_168.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_35.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_15.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_143.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_41.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_140.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_29.jpg')]

# %%
fnames = get_image_files(path)
fnames[:10]
# Out:
# [PosixPath('IMÁGENES FILTRADAS/BURKITT_32.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_6.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_20.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_16.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_21.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/HCL_10.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_110.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/LLC_48.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/FOLICULAR_85.jpg'),
#  PosixPath('IMÁGENES FILTRADAS/BURKITT_73.jpg')]

# %%
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path, fnames, pat, ds_tfms=get_transforms(), size=363).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
train = data.train_ds
valid = data.valid_ds
# train.to_csv(dest='/shared/TFG_marc/prueba.csv')

# %%
df= pd.concat([train.to_df(),valid.to_df()], ignore_index=False)
df.head()
# Out:
#                    x          y
# 0     BURKITT_32.jpg    BURKITT
# 1         HCL_21.jpg        HCL
# 2         HCL_10.jpg        HCL
# 3  FOLICULAR_110.jpg  FOLICULAR
# 4         LLC_48.jpg        LLC

# %%
df.columns=['Image','Id']
df.head()
# Out:
#                Image         Id
# 0     BURKITT_32.jpg    BURKITT
# 1         HCL_21.jpg        HCL
# 2         HCL_10.jpg        HCL
# 3  FOLICULAR_110.jpg  FOLICULAR
# 4         LLC_48.jpg        LLC

# %%
print(data.classes)
# Out:
# ['BURKITT', 'FOLICULAR', 'HCL', 'LCM', 'LLC']

# %%
len(data.classes),data.c
# Out:
# (5, 5)

# %%
df['Id'].value_counts()[:5]
# Out:
# BURKITT      188
# FOLICULAR    149
# LCM           59
# LLC           57
# HCL           48
# Name: Id, dtype: int64

# %%
df['target'] = 1
df1 = df.copy()
df['target'] = 0
df = df.append(df1)
target_col = 2

# %%
df.head()
# Out:
#                Image         Id  target
# 0     BURKITT_32.jpg    BURKITT       0
# 1         HCL_21.jpg        HCL       0
# 2         HCL_10.jpg        HCL       0
# 3  FOLICULAR_110.jpg  FOLICULAR       0
# 4         LLC_48.jpg        LLC       0

# %%
df.shape
# Out:
# (1002, 3)

# %% [markdown]
# ## ITEMBASE Y ITEMLIST

# %%
mean, std = torch.tensor(imagenet_stats)

class SiamImage(ItemBase):
    def __init__(self, img1, img2): 
        self.img1, self.img2 = img1, img2
        self.obj, self.data = (img1, img2), [(img1.data-mean[...,None,None])/std[...,None,None], (img2.data-mean[...,None,None])/std[...,None,None]]
    def apply_tfms(self, tfms,*args, **kwargs):
        self.img1 = self.img1.apply_tfms(tfms, *args, **kwargs)
        self.img2 = self.img2.apply_tfms(tfms, *args, **kwargs)
        self.data = [(self.img1.data-mean[...,None,None])/std[...,None,None], (self.img2.data-mean[...,None,None])/std[...,None,None]]
        return self
    def __repr__(self): return f'{self.__class__.__name__} {self.img1.shape, self.img2.shape}'
    def to_one(self):
        return Image(mean[...,None,None]+torch.cat(self.data,2)*std[...,None,None])

# %%
class SiamImageItemList(ImageList):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def __len__(self)->int: return len(self.items) or 1 

    def get(self, i):
        match=1
        if i>=len(self.items)//2:
            match = 0
        fn = self.items[i]
        img1 = super().get(i) 

        imgs = self.inner_df.Image.values
        ids = self.inner_df.Id.values
        wcls = ids[i]
        simgs = imgs[ids == wcls]
        dimgs = imgs[ids != wcls]
        if len(simgs)==1 and match==1:
            fn2=fn
        else:
            while True:
                np.random.shuffle(simgs)
                np.random.shuffle(dimgs)
                if simgs[0] != fn:
                    fn2 = [simgs[0] if match==1 else dimgs[0]][0]
                    break
            fn2 = self.items[np.where(imgs==fn2)[0][0]]
        img2 = super().open(fn2) 
        return SiamImage(img1, img2)

    def reconstruct(self, t): return SiamImage(mean[...,None,None]+t[0]*std[...,None,None], mean[...,None,None]+t[1]*std[...,None,None])

    def show_xys(self, xs, ys, figsize:Tuple[int,int]=(9,10), **kwargs):
        rows = int(math.sqrt(len(xs)))
        fig, axs = plt.subplots(rows,rows,figsize=figsize)
        for i, ax in enumerate(axs.flatten() if rows > 1 else [axs]):
            xs[i].to_one().show(ax=ax, y=ys[i], **kwargs)
        plt.tight_layout()

# %%
whl_tfms = get_transforms()
bs = 8

# %%
data = (SiamImageItemList.from_df(df=df, path=path, cols=0)
         .split_by_rand_pct(valid_pct=0.2, seed=34)
         .label_from_df(cols=target_col, label_cls=FloatList)
         .transform(whl_tfms, size=224)
         .databunch(bs=bs))

data.show_batch(2)

# %%
x = next(iter(data.train_dl))
t=x[0][0][0].cpu()
to = mean[...,None,None] + t* std[...,None,None]
import torchvision
ti = torchvision.transforms.ToPILImage(to)
plt.imshow(to.numpy().transpose(1,2,0))

# %% [markdown]
# ## SNN Y LOSS FUNCTION

# %%
from fastai.vision import learner

class SiameseNet(nn.Module):
    def __init__(self, arch=models.resnet34, lin_ftrs=[256, 128], emb_sz=128,ps=0.5, bn_final=False):
        super(SiameseNet, self).__init__()
        self.arch, self.emb_sz = arch, emb_sz
        self.lin_ftrs, self.ps, self.bn_final = lin_ftrs, ps, bn_final
        self.body = learner.create_body(self.arch, True, learner.cnn_config(self.arch)['cut'])
        self.head = learner.create_head(num_features_model(self.body) * 1, self.emb_sz, self.lin_ftrs, self.ps,self.bn_final)
        self.cnn = nn.Sequential(self.body, self.head)

    def forward(self, x1, x2):
        output1 = self.cnn(x1)
        output2 = self.cnn(x2)
        return output1, output2

    def get_embedding(self, x):
        return self.cnn(x)

# %%
class ContrastiveLoss(nn.Module):

    def __init__(self, margin=5.):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        
    def forward(self, ops, target, size_average=True):
        op1, op2 = ops[0], ops[1]
        dist = F.pairwise_distance(op1, op2)
        pdist = dist*target
        ndist = dist*(1-target)
        loss = 0.5* ((pdist**2) + (F.relu(self.margin-ndist)**2))
        return loss.mean() if size_average else losses.sum()

# %% [markdown]
# ## INSTANCIAR EL MODELO

# %%
model = SiameseNet().cuda()
apply_init(model.head, nn.init.kaiming_normal_)
loss_func=ContrastiveLoss().cuda()
siam_learner = Learner(data, model, loss_func=loss_func, model_dir=Path(os.getcwd()) )

# %%
siam_learner.model
# Out:
# SiameseNet(
#   (body): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (head): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten()
#     (2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.25)
#     (8): Linear(in_features=256, out_features=128, bias=True)
#     (9): ReLU(inplace)
#     (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout(p=0.5)
#     (12): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (cnn): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): Sequential(
#       (0): AdaptiveAvgPool2d(output_size=1)
#       (1): Flatten()
#       (2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Dropout(p=0.25)
#       (4): Linear(in_features=512, out_features=256, bias=True)
#       (5): ReLU(inplace)
#       (6): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): Dropout(p=0.25)
#       (8): Linear(in_features=256, out_features=128, bias=True)
#       (9): ReLU(inplace)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): Dropout(p=0.5)
#       (12): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
# )

# %%
siam_learner.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.405497</td>
#       <td>11.413124</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>9.686978</td>
#       <td>11.573508</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>9.649706</td>
#       <td>11.996691</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>9.680661</td>
#       <td>11.618264</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>9.440818</td>
#       <td>11.769794</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
siam_learner.save('stage-1')

# %%
siam_learner.unfreeze()

# %%
siam_learner.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.816053</td>
#       <td>11.234769</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
siam_learner.load('stage-1');
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type ContrastiveLoss. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type SiameseNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
siam_learner.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
siam_learner.recorder.plot()

# %%
siam_learner.fit_one_cycle(5, slice(1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.199944</td>
#       <td>11.661616</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>9.373597</td>
#       <td>11.792001</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>9.526206</td>
#       <td>11.715299</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>9.592981</td>
#       <td>11.738335</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>9.495369</td>
#       <td>11.683617</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
siam_learner.save('stage-2')

# %%
def extract_embedding(dl, ds, mdl):
    mdl.eval()
    with torch.no_grad():
        preds = torch.zeros((len(ds), 128))
        start=0
        for cnt, (x, y) in enumerate(dl, start=0):
            size = x[0].shape[0]
            preds[start:start+size,:] = model.get_embedding(x[0])
            start+= size
        return preds

# %%
data = (SiamImageItemList.from_df(df=df, path=path, cols=0)
         .split_by_rand_pct(valid_pct=1, seed=34)
         .label_from_df(cols=target_col, label_cls=FloatList)
         .transform(whl_tfms, size=224)
         .databunch(bs=4))
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/data_block.py:451: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")

# %%
dl = data.valid_dl
ds = data.valid_ds
res = extract_embedding(dl, ds, model)

# %%
res.numpy().shape
# Out:
# (1002, 128)

# %%
whlc= np.array([df.loc[df.Image == Path(i.split(sep='/')[1]), 'Id'].values[0] for i in ds.items])

# %%
res.shape
# Out:
# torch.Size([1002, 128])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
pca.fit(res)
embs2d = pca.transform(res)

# %%
import colorsys
def random_colors(N, bright=True):
    
    brightness = 1.0 if bright else 0.7
    hsv = [(i / N, 1, brightness) for i in range(N)]
    colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
    random.shuffle(colors)
    return colors

def plot_embeddings(embeddings=None,whlc=None, xlim=None, ylim=None):

    plt.figure(figsize=(10,10))
    for cnt, i in enumerate(set(whlc)):

        inds = np.where(whlc==i)[0]
        plt.scatter(embeddings[inds,0], embeddings[inds,1], alpha=0.5, color=colors[cnt])
    if xlim:
        plt.xlim(xlim[0], xlim[1])
    if ylim:
        plt.ylim(ylim[0], ylim[1])
    plt.legend(set(whlc))

# %%
colors = random_colors(len(set(whlc)))
plot_embeddings(embs2d,whlc, xlim=None, ylim=None)

# %%
features = pd.DataFrame(res.numpy())
features['label'] = whlc
features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.036965 -0.069552  0.057329 -0.104517  0.013639 -0.004117  0.013059
# 1  0.036984 -0.067429  0.056542 -0.106137  0.018400 -0.004189  0.019371
# 2  0.013509 -0.067462  0.045255 -0.110027  0.012371 -0.000303 -0.038605
# 3  0.037674 -0.122451  0.011107  0.057956 -0.032724  0.062910  0.049284
# 4  0.026999 -0.074734  0.050553 -0.099676  0.013483  0.001002 -0.019183
#
#           7         8         9  ...       119       120       121       122  \
# 0 -0.033392  0.009456  0.058713  ... -0.035874 -0.063857  0.029661  0.056065
# 1 -0.032531  0.005927  0.071638  ... -0.039266 -0.068043  0.013119  0.073877
# 2 -0.000885  0.011640 -0.041736  ...  0.003929 -0.026791  0.107112  0.015598
# 3  0.014693  0.159980 -0.000326  ... -0.135089 -0.213414  0.003578  0.066471
# 4 -0.009036 -0.002122  0.002618  ...  0.000743 -0.042349  0.072841  0.050926
#
#         123       124       125       126       127      label
# 0  0.054704  0.046920  0.054544 -0.045192  0.045882  FOLICULAR
# 1  0.074677  0.051798  0.052754 -0.056072  0.032160        LLC
# 2  0.002615 -0.004424  0.091722 -0.012715  0.113492  FOLICULAR
# 3  0.012377  0.112118 -0.062099 -0.087622  0.099048        LCM
# 4  0.035464  0.019228  0.080809 -0.025482  0.078288        LCM
#
# [5 rows x 129 columns]

# %%
features.shape
# Out:
# (1002, 129)

# %%
def oneshot(model,img1,img2):
    output1,output2 = model(img1.cuda(),img2.cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    return euclidean_distance

# %%
df_original = df1.reset_index(drop=True)
df_original.head()
# Out:
#                Image         Id  target
# 0     BURKITT_32.jpg    BURKITT       1
# 1         HCL_21.jpg        HCL       1
# 2         HCL_10.jpg        HCL       1
# 3  FOLICULAR_110.jpg  FOLICULAR       1
# 4         LLC_48.jpg        LLC       1

# %%
df_original
# Out:
#                  Image         Id  target
# 0       BURKITT_32.jpg    BURKITT       1
# 1           HCL_21.jpg        HCL       1
# 2           HCL_10.jpg        HCL       1
# 3    FOLICULAR_110.jpg  FOLICULAR       1
# 4           LLC_48.jpg        LLC       1
# 5     FOLICULAR_85.jpg  FOLICULAR       1
# 6       BURKITT_73.jpg    BURKITT       1
# 7      BURKITT_138.jpg    BURKITT       1
# 8    FOLICULAR_147.jpg  FOLICULAR       1
# 9       BURKITT_10.jpg    BURKITT       1
# 10     BURKITT_135.jpg    BURKITT       1
# 11           HCL_6.jpg        HCL       1
# 12          LCM_23.jpg        LCM       1
# 13   FOLICULAR_107.jpg  FOLICULAR       1
# 14    FOLICULAR_31.jpg  FOLICULAR       1
# 15           HCL_3.jpg        HCL       1
# 16      BURKITT_56.jpg    BURKITT       1
# 17      BURKITT_96.jpg    BURKITT       1
# 18   FOLICULAR_122.jpg  FOLICULAR       1
# 19     BURKITT_108.jpg    BURKITT       1
# 20      BURKITT_24.jpg    BURKITT       1
# 21      BURKITT_31.jpg    BURKITT       1
# 22      BURKITT_40.jpg    BURKITT       1
# 23          LCM_10.jpg        LCM       1
# 24     BURKITT_125.jpg    BURKITT       1
# 25          LCM_31.jpg        LCM       1
# 26       BURKITT_2.jpg    BURKITT       1
# 27      BURKITT_42.jpg    BURKITT       1
# 28     BURKITT_155.jpg    BURKITT       1
# 29   FOLICULAR_114.jpg  FOLICULAR       1
# ..                 ...        ...     ...
# 471    FOLICULAR_8.jpg  FOLICULAR       1
# 472         LLC_44.jpg        LLC       1
# 473          LLC_1.jpg        LLC       1
# 474     BURKITT_58.jpg    BURKITT       1
# 475     BURKITT_33.jpg    BURKITT       1
# 476  FOLICULAR_145.jpg  FOLICULAR       1
# 477     BURKITT_26.jpg    BURKITT       1
# 478     BURKITT_84.jpg    BURKITT       1
# 479     BURKITT_86.jpg    BURKITT       1
# 480         LCM_55.jpg        LCM       1
# 481  FOLICULAR_108.jpg  FOLICULAR       1
# 482   FOLICULAR_16.jpg  FOLICULAR       1
# 483     BURKITT_92.jpg    BURKITT       1
# 484     BURKITT_83.jpg    BURKITT       1
# 485  FOLICULAR_104.jpg  FOLICULAR       1
# 486         LCM_16.jpg        LCM       1
# 487     BURKITT_78.jpg    BURKITT       1
# 488         LLC_19.jpg        LLC       1
# 489    BURKITT_142.jpg    BURKITT       1
# 490         LLC_35.jpg        LLC       1
# 491     BURKITT_81.jpg    BURKITT       1
# 492    BURKITT_186.jpg    BURKITT       1
# 493    BURKITT_175.jpg    BURKITT       1
# 494   FOLICULAR_33.jpg  FOLICULAR       1
# 495         LLC_16.jpg        LLC       1
# 496     BURKITT_18.jpg    BURKITT       1
# 497   FOLICULAR_12.jpg  FOLICULAR       1
# 498         LLC_46.jpg        LLC       1
# 499    FOLICULAR_9.jpg  FOLICULAR       1
# 500    BURKITT_178.jpg    BURKITT       1
#
# [501 rows x 3 columns]

# %%
im1 = open_image( path / df_original.Image[15])
im1.show()
plt.title(df_original.Id[15])
plt.show()

# %%
im2 = open_image( path / df_original.Image[490])
im2.show()
plt.title(df_original.Id[490])
plt.show()

# %%
oneshot(siam_learner.model, im1.resize(224).data[None,:,:,:], im2.resize(224).data[None,:,:,:])
# Out:
# tensor([1.3356], device='cuda:0', grad_fn=<NormBackward1>)

# %%
def obtenervector(im1, im2, mdl):
    mdl.eval()
    with torch.no_grad():
        out1, out2 = mdl(im1,im2)
        return out1, out2

# %%
c=0
for cnt, (x, y) in enumerate(dl, start=0):
    c = c+1
    o1,o2 = model(x[0],x[1])
    v = x[0]
    if c == 1:
        break

# %%
oneshot(siam_learner.model, v[[2]], v[[1]])
# Out:
# tensor([1.7606], device='cuda:0', grad_fn=<NormBackward1>)

# %%
plt.imshow(v.cpu().numpy()[3][0])

# %%
oneshot(siam_learner.model, im1.resize(224).data[None,:,:,:], im2.resize(224).data[None,:,:,:])
# Out:
# tensor([0.0024], device='cuda:0', grad_fn=<NormBackward1>)

# %%
im1.resize(224)
# Out:
# Image (3, 224, 224)
